# %%
#Importing the libraries
import pandas as crdcd_fdpps
import seaborn as crdcd_fdsea
import matplotlib.pyplot as crdcd_fdmt
import warnings as crdcd_fdwrin
crdcd_fdwrin.filterwarnings("ignore")

# %%
crdcd_fd = crdcd_fdpps.read_csv('UCI_Credit_Card.csv')
crdcd_fdpps.set_option('display.max_columns', None)
crdcd_fd.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2     3913.0     3102.0      689.0        0.0        0.0
# 1      0      2     2682.0     1725.0     2682.0     3272.0     3455.0
# 2      0      0    29239.0    14027.0    13559.0    14331.0    14948.0
# 3      0      0    46990.0    48233.0    49291.0    28314.0    28959.0
# 4      0      0     8617.0     5670.0    35835.0    20940.0    19146.0
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
crdcd_fd.shape
# Out:
# (30000, 25)

# %% [markdown]
# * This credit card dataset 30000 rows and 25 columns are present!

# %%
crdcd_fd[50:75]
# Out:
#     ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 50  51    70000.0    1          3         2   42      1      2      2      2
# 51  52   100000.0    2          3         3   43      0      0      0      0
# 52  53   310000.0    2          2         1   49     -2     -2     -2     -2
# 53  54   180000.0    2          1         2   25      1      2      0      0
# 54  55   150000.0    2          1         2   29      2      0      0      0
# 55  56   500000.0    2          1         1   45     -2     -2     -2     -2
# 56  57   180000.0    2          3         1   34      0      0      0     -1
# 57  58   180000.0    2          2         1   34      0      0      0      0
# 58  59   200000.0    2          1         2   34     -1      3      2      2
# 59  60   400000.0    2          2         1   29      0      0      0      0
# 60  61   500000.0    2          3         1   28      0      0      0      0
# ...

# %%
crdcd_fd.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
crdcd_fd.nunique()
# Out:
# ID                            30000
# LIMIT_BAL                        81
# SEX                               2
# EDUCATION                         7
# MARRIAGE                          4
# AGE                              56
# PAY_0                            11
# PAY_2                            11
# PAY_3                            11
# PAY_4                            11
# PAY_5                            10
# PAY_6                            10
# BILL_AMT1                     22723
# BILL_AMT2                     22346
# BILL_AMT3                     22026
# BILL_AMT4                     21548
# BILL_AMT5                     21010
# BILL_AMT6                     20604
# PAY_AMT1                       7943
# PAY_AMT2                       7899
# PAY_AMT3                       7518
# PAY_AMT4                       6937
# PAY_AMT5                       6897
# PAY_AMT6                       6939
# default.payment.next.month        2
# dtype: int64

# %%
crdcd_fd['SEX'].value_counts()
# Out:
# SEX
# 2    18112
# 1    11888
# Name: count, dtype: int64

# %% [markdown]
# * default.payment.next.month(1=yes,0=no)

# %%
crdcd_fd= crdcd_fd.drop(['ID'], axis=1)
crdcd_fd
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0        20000.0    2          2         1   24      2      2     -1     -1
# 1       120000.0    2          2         2   26     -1      2      0      0
# 2        90000.0    2          2         2   34      0      0      0      0
# 3        50000.0    2          2         1   37      0      0      0      0
# 4        50000.0    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995   220000.0    1          3         1   39      0      0      0      0
# 29996   150000.0    1          3         2   43     -1     -1     -1     -1
# 29997    30000.0    1          2         2   37      4      3      2     -1
# 29998    80000.0    1          3         1   41      1     -1      0      0
# 29999    50000.0    1          2         1   46      0      0      0      0
#
# ...

# %%
#### Steps of preprocessing data
### checking null
crdcd_fd.isna().any()
# Out:
# LIMIT_BAL                     False
# SEX                           False
# EDUCATION                     False
# MARRIAGE                      False
# AGE                           False
# PAY_0                         False
# PAY_2                         False
# PAY_3                         False
# PAY_4                         False
# PAY_5                         False
# PAY_6                         False
# BILL_AMT1                     False
# BILL_AMT2                     False
# BILL_AMT3                     False
# BILL_AMT4                     False
# BILL_AMT5                     False
# BILL_AMT6                     False
# PAY_AMT1                      False
# PAY_AMT2                      False
# PAY_AMT3                      False
# PAY_AMT4                      False
# PAY_AMT5                      False
# PAY_AMT6                      False
# default.payment.next.month    False
# dtype: bool

# %%
crdcd_fd.shape
# Out:
# (30000, 24)

# %%
## find duplicates
crdcd_fd .duplicated()
crdcd_fd_D = crdcd_fd[crdcd_fd.duplicated()]
crdcd_fd_D
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 1980    150000.0    2          1         1   38      1     -2     -2     -2
# 4585    150000.0    2          1         1   31      1     -2     -2     -2
# 6022    210000.0    2          1         2   39      1     -2     -2     -2
# 6466    210000.0    2          2         1   49      1     -2     -2     -2
# 7319    500000.0    1          1         1   43      1     -2     -2     -2
# 8320    360000.0    1          2         1   41      1     -2     -2     -2
# 10250    50000.0    1          2         2   26      1     -2     -2     -2
# 13106   360000.0    2          1         1   49      1     -2     -2     -2
# 14294    20000.0    1          2         2   24      2      2      4      4
# 15458   160000.0    1          2         2   28     -2     -2     -2     -2
# 15617   200000.0    2          2         2   26     -2     -2     -2     -2
# ...

# %%
crdcd_fd=crdcd_fd.drop_duplicates()
crdcd_fd
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0        20000.0    2          2         1   24      2      2     -1     -1
# 1       120000.0    2          2         2   26     -1      2      0      0
# 2        90000.0    2          2         2   34      0      0      0      0
# 3        50000.0    2          2         1   37      0      0      0      0
# 4        50000.0    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995   220000.0    1          3         1   39      0      0      0      0
# 29996   150000.0    1          3         2   43     -1     -1     -1     -1
# 29997    30000.0    1          2         2   37      4      3      2     -1
# 29998    80000.0    1          3         1   41      1     -1      0      0
# 29999    50000.0    1          2         1   46      0      0      0      0
#
# ...

# %%
correlation = crdcd_fd.corr()
crdcd_fdmt.figure(figsize=(18,12))
# Create a heatmap with annotations
crdcd_fdsea.heatmap(correlation, annot=True, fmt='.2f')
crdcd_fdmt.title('Correlation Heatmap')
crdcd_fdmt.show();

# %%
#### Countplot for credit card- 'default.payment.next.month'
crdcd_fdsea.countplot(x ='default.payment.next.month', data = crdcd_fd,color='pink')
crdcd_fdmt.title("credit card 'default.payment.next.month'",size=10)
crdcd_fdmt.show()

# %% [markdown]
# (1=yes,0=no)
#
# * Default credit card payments are less.

# %%
#### credit card member's sex and marriage status
crdcd_fdsea.countplot(x ='SEX', hue = "MARRIAGE", data = crdcd_fd)
crdcd_fdmt.legend(loc='upper left', bbox_to_anchor=(1.2, .80))
crdcd_fdmt.title("credit card member's sex and marriage status'")
crdcd_fdmt.show()

# %% [markdown]
# 1=married, 2=single, 3= others
#
# *unmarried credit card members are high. In which Female unmarried members are majority compared to Males

# %%
#### Distplot for credit card members age details
crdcd_fdmt.figure(figsize = (6, 4))
crdcd_fdsea.distplot(crdcd_fd['AGE'], color='red')
crdcd_fdmt.title("credit card members age details")
crdcd_fdmt.ylabel("count")
crdcd_fdmt.show()

# %% [markdown]
# * Age of credit card members lies between 20 to 80

# %%
#### Credit card members age and limited balance
crdcd_fdsea.scatterplot(data=crdcd_fd, x="LIMIT_BAL", y="AGE")
crdcd_fdmt.title("credit card members age and their limited balance details")
crdcd_fdmt.show()

# %% [markdown]
# * Members those having age between 25 to 50, whose credit card limited balance amount is high.

# %%
crdcd_fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29965 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   29965 non-null  float64
#  1   SEX                         29965 non-null  int64
#  2   EDUCATION                   29965 non-null  int64
#  3   MARRIAGE                    29965 non-null  int64
#  4   AGE                         29965 non-null  int64
#  5   PAY_0                       29965 non-null  int64
#  6   PAY_2                       29965 non-null  int64
#  7   PAY_3                       29965 non-null  int64
#  8   PAY_4                       29965 non-null  int64
#  9   PAY_5                       29965 non-null  int64
#  10  PAY_6                       29965 non-null  int64
#  11  BILL_AMT1                   29965 non-null  float64
#  12  BILL_AMT2                   29965 non-null  float64
# ...

# %%
crdcd_fdsea.countplot(x ='SEX', data = crdcd_fd)
crdcd_fdmt.title("Sex Details")
crdcd_fdmt.show()

# %% [markdown]
# ** 1=male, 2=female
#
# ** Female credit card holders are majority.

# %%
crdcd_fdsea.countplot(x ='EDUCATION', data = crdcd_fd)
crdcd_fdmt.title("Education Details")
crdcd_fdmt.show()

# %% [markdown]
# 1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown.
#
#
# university passed members are majority.

# %%
crdcd_fdsea.countplot(x ='MARRIAGE', data = crdcd_fd, color='grey')
crdcd_fdmt.title("Marriage Details")
crdcd_fdmt.show()

# %% [markdown]
# 1=married, 2=single, 3=others
#
# * Unmarried credit card holders are majority.

# %% [markdown]
# **Repayment status for 7 months**

# %%
for o in ['PAY_0','PAY_2','PAY_3','PAY_4','PAY_5','PAY_6']:
  vable = crdcd_fdsea.distplot(crdcd_fd[o], color ='green', bins = 25)
  vable.set(title =str(o)+ ' Repayment status')
  crdcd_fdmt.show()

# %% [markdown]
# [-1=pay duly,
# 1=payment delay for one month,
# 2=payment delay for two months, ...
# 8=payment delay for eight months,
# 9=payment delay for nine months and above]
#
# * so most of the members pays at correct time without any delay.

# %% [markdown]
# **Amount of bill statement for 6 months**

# %%
for o in ['BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6']:
  vable = crdcd_fdsea.distplot(crdcd_fd[o], color ='red', bins = 25)
  vable.set(title =str(o)+ '- Amount of bill statement')
  crdcd_fdmt.show()

# %% [markdown]
# * Statement shows bill amount of month september 2005 to April 2005.

# %% [markdown]
# **Amount of previous payment for 6 months**

# %%
for o in ['PAY_AMT1','PAY_AMT2','PAY_AMT3','PAY_AMT4','PAY_AMT5','PAY_AMT6']:
  vable = crdcd_fdsea.distplot(crdcd_fd[o], color ='tan', bins = 25)
  vable.set(title =str(o)+ '- Amount of previous payment')
  crdcd_fdmt.show()

# %% [markdown]
# * Statement shows Amount of previous payment in month september 2005 to April 2005

# %%
vable = crdcd_fdsea.boxplot(y ="LIMIT_BAL", x ="default.payment.next.month", data = crdcd_fd, palette = "Set2")

vable.set(ylabel ="balance limit", xlabel = "default payment", title ='default payment with balance limit');

# %% [markdown]
# Default payment (1=yes, 0=no)

# %% [markdown]
# * Non default payment accounts are having high amount of balance limit.

# %%
crdcd_fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29965 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   29965 non-null  float64
#  1   SEX                         29965 non-null  int64
#  2   EDUCATION                   29965 non-null  int64
#  3   MARRIAGE                    29965 non-null  int64
#  4   AGE                         29965 non-null  int64
#  5   PAY_0                       29965 non-null  int64
#  6   PAY_2                       29965 non-null  int64
#  7   PAY_3                       29965 non-null  int64
#  8   PAY_4                       29965 non-null  int64
#  9   PAY_5                       29965 non-null  int64
#  10  PAY_6                       29965 non-null  int64
#  11  BILL_AMT1                   29965 non-null  float64
#  12  BILL_AMT2                   29965 non-null  float64
# ...
